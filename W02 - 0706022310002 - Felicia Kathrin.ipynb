# %%
import pandas as pd

# Download the CSV file from the URL
url = "https://raw.githubusercontent.com/NathaliaMinoque/datasets/refs/heads/main/jabodetabek_house_price.csv"
df = pd.read_csv(url, sep=',')

df.head()

# Melakukan load dataset using pandas dataframe dan menampilkan 5 rows pertama data
# Out:
#                                                  url   price_in_rp  \
# 0  https://www.rumah123.com/properti/bekasi/hos11...  2.990000e+09
# 1  https://www.rumah123.com/properti/bekasi/hos10...  1.270000e+09
# 2  https://www.rumah123.com/properti/bekasi/hos10...  1.950000e+09
# 3  https://www.rumah123.com/properti/bekasi/hos10...  3.300000e+09
# 4  https://www.rumah123.com/properti/bekasi/hos10...  4.500000e+09
#
#                                                title  \
# 0  Rumah cantik Sumarecon Bekasi\nLingkungan asri...
# 1          Rumah Kekinian, Magenta Summarecon Bekasi
# 2  Rumah Cantik 2 Lantai Cluster Bluebell Summare...
# 3  Rumah Mewah 2Lantai L10x18 C di Cluster VERNON...
# 4  Rumah Hoek di Cluster Maple Summarecon Bekasi,...
#
#                      address           district     city       lat  \
# 0  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# 1  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# ...

# %%
df.info()

# Mengetahui kolom apa saja pada data serta jumlah null value pada data dan type data nya.
# Dari sini dapat mulai melakukan strategi untuk mengisi null value dengan nilai yang cocok
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3553 entries, 0 to 3552
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   3553 non-null   object
#  1   price_in_rp           3553 non-null   float64
#  2   title                 3553 non-null   object
#  3   address               3553 non-null   object
#  4   district              3553 non-null   object
#  5   city                  3553 non-null   object
#  6   lat                   3553 non-null   float64
#  7   long                  3553 non-null   float64
#  8   facilities            3553 non-null   object
#  9   property_type         3552 non-null   object
#  10  ads_id                3549 non-null   object
#  11  bedrooms              3519 non-null   float64
#  12  bathrooms             3524 non-null   float64
#  13  land_size_m2          3551 non-null   float64
# ...

# %%
df.describe()

# Mengetahui deskripsi dari seluruh data. Dari informasi dibawah diketahui bahwa terdapat minimal bedrooms 1 serta max nya 99.
# Contoh lainnya, pada building size dengan minimal 1m2 dan max nya 6000m2. Range yang terlalu besar ini dapat menunjukan adanya outliers.
# Hal ini menunjukan bahwa distribusi data ini kurang merata, ada rumah yang cuman punya 1 kamar, sedangkan ada yang punya 99 kamar.
# Selain itu data max pada year_built juga tidak masuk akal yaitu 2052 dimasa depan, kemungkinan ada kesalahan input.
# Out:
#         price_in_rp          lat         long     bedrooms    bathrooms  \
# count  3.553000e+03  3553.000000  3553.000000  3519.000000  3524.000000
# mean   4.191685e+09    -6.324721   106.792881     3.326513     2.624858
# std    1.375067e+10     0.129245     0.172159     2.672148     2.696497
# min    4.200000e+07    -6.894828   106.402315     1.000000     1.000000
# 25%    8.000000e+08    -6.397933   106.687295     2.000000     2.000000
# 50%    1.500000e+09    -6.300733   106.799954     3.000000     2.000000
# 75%    3.590000e+09    -6.231754   106.874766     4.000000     3.000000
# max    5.800000e+11    -6.102478   109.771691    99.000000    99.000000
#
#        land_size_m2  building_size_m2     carports  maid_bedrooms  \
# count   3551.000000       3551.000000  3553.000000    3553.000000
# mean     204.806815        186.587440     1.197861       0.496482
# std      402.127746        248.443471     1.114996       0.685723
# ...

# %%
df = df.drop(['url', 'ads_id'], axis=1)
df.head()

# Selajutnya melakukan drop data, menurut saya kolom url dan ads_id tidak bisa digunakan untuk analisis,
# sehingga saya memilih untuk membuang semua data di kolom tersebut.
# Out:
#     price_in_rp                                              title  \
# 0  2.990000e+09  Rumah cantik Sumarecon Bekasi\nLingkungan asri...
# 1  1.270000e+09          Rumah Kekinian, Magenta Summarecon Bekasi
# 2  1.950000e+09  Rumah Cantik 2 Lantai Cluster Bluebell Summare...
# 3  3.300000e+09  Rumah Mewah 2Lantai L10x18 C di Cluster VERNON...
# 4  4.500000e+09  Rumah Hoek di Cluster Maple Summarecon Bekasi,...
#
#                      address           district     city       lat  \
# 0  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# 1  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# 2  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# 3  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# 4  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
#
#          long                                         facilities  \
# 0  106.986275       Tempat Jemuran, Jalur Telepon, Taman,  Taman
# ...

# %%
# Calculate null values and percentage
null_counts = df.isnull().sum()
null_percentages = (null_counts / len(df)) * 100

# Create a DataFrame for columns with null values
null_df = pd.DataFrame({'Null Count': null_counts, 'Null Percentage': null_percentages})

# Filter for columns with null values
null_df = null_df[null_df['Null Count'] > 0]


# Format the percentage with two decimal places and % symbol
null_df['Null Percentage'] = null_df['Null Percentage'].map('{:.2f}%'.format)


null_df

# Lalu saya ingin mengetahui jumlah data yang null di setiap kolom beserta persentase nya
# Out:
#                       Null Count Null Percentage
# property_type                  1           0.03%
# bedrooms                      34           0.96%
# bathrooms                     29           0.82%
# land_size_m2                   2           0.06%
# building_size_m2               2           0.06%
# certificate                  141           3.97%
# floors                         6           0.17%
# building_age                1445          40.67%
# year_built                  1445          40.67%
# property_condition           246           6.92%
# building_orientation        1647          46.36%
# furnishing                   387          10.89%

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the horizontal bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
sns.barplot(x='Null Count', y=null_df.index, data=null_df, orient='h', palette='rainbow')
plt.xlabel('Number of Null Values', fontsize=12)
plt.ylabel('Columns', fontsize=12)
plt.title('Null Values per Column', fontsize=14)

# Add labels to the bars
for i, v in enumerate(null_df['Null Count']):
    plt.text(v + 1, i, str(v), color='black', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# ini visualisasi null value setiap kolom
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23016\1430080420.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Null Count', y=null_df.index, data=null_df, orient='h', palette='rainbow')

# %%
# Display unique values for each column
for col in df.columns:
  print(f"Unique values for column '{col}':")
  print(df[col].unique())
  print("-" * 20)

  # Informasi dibawah menunjukan unique values setiap kolom data.
  # Fungsi nya, kita dapat mengecek sekilas terhadap isi data nya, apakah sebagian besar sudah benar atau belom
# Out:
# Unique values for column 'price_in_rp':
# [2.99e+09 1.27e+09 1.95e+09 3.30e+09 4.50e+09 2.70e+09 2.35e+09 2.90e+09
#  2.55e+09 9.52e+08 1.80e+09 2.50e+09 5.36e+09 2.25e+09 2.45e+09 1.25e+08
#  1.98e+09 7.64e+08 2.00e+09 4.80e+08 1.90e+09 3.00e+08 5.27e+09 2.80e+09
#  2.71e+09 5.00e+08 4.39e+08 8.00e+08 8.50e+08 7.00e+08 4.95e+09 1.30e+09
#  1.20e+09 2.65e+09 4.25e+08 2.80e+08 9.99e+08 5.75e+09 1.50e+09 6.80e+09
#  3.00e+09 1.68e+08 8.70e+08 4.95e+08 2.75e+08 1.44e+09 3.65e+08 3.50e+08
#  3.51e+08 3.93e+08 3.92e+08 4.40e+08 4.01e+08 1.99e+09 1.15e+09 3.20e+09
#  9.50e+08 1.25e+09 1.28e+09 8.95e+08 1.45e+09 6.90e+08 1.35e+09 1.00e+09
#  2.85e+09 3.42e+08 3.27e+08 9.75e+08 1.37e+09 2.15e+09 1.55e+09 1.40e+09
#  7.99e+08 7.79e+08 7.75e+08 1.75e+09 7.50e+08 4.30e+09 5.20e+08 6.85e+08
#  9.30e+08 2.10e+09 2.17e+09 6.20e+08 1.60e+09 9.70e+08 5.75e+08 9.00e+08
#  5.25e+08 5.10e+08 1.65e+09 4.20e+07 5.99e+08 1.68e+09 1.56e+09 1.18e+09
# ...

# %%
df = df.dropna(subset=["property_type"])

# Selanjutnya melakukan drop pada row data yang memiliki null value di kolom
# property_type. Pada kasus ini tidak masalah untuk membuang data karena
# hanya 1 data dari 3553 yang dibuang sehingga tidak akan mempengaruhi analisis
# data keseluruhan

# %%
df = df.dropna(subset=["floors"])

# Selanjutnya melakukan drop pada row data yang memiliki null value di kolom
# floors. Pada kasus ini tidak masalah untuk membuang data karena
# hanya 6 data dari 3553 yang dibuang sehingga tidak akan mempengaruhi analisis
# data keseluruhan

# %%
df = df.dropna(subset=["land_size_m2"])
df = df.dropna(subset=["building_size_m2"])

# Selanjutnya melakukan drop pada row data yang memiliki null value di kolom
# land_size_m2 dan building_size_m2. Pada kasus ini tidak masalah untuk membuang data karena
# hanya 2 data dari 3553 data yang dibuang sehingga tidak akan mempengaruhi analisis
# data keseluruhan

# %%
df['bedrooms'].fillna(df['bedrooms'].median(), inplace=True)

# Mengisi null value pada kolom bedrooms menggunakan median,
# dikarenakan pada data ini distribusi bedrooms cukup besar
# ada yang hanya mempunyai 1 bedrooms tapi juga ada yang mempunyai
# hingga 99 bedrooms. Sehingga bisa lebih menyeimbangkan outliers
# dibandingkan memakai modus
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23016\2996948094.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bedrooms'].fillna(df['bedrooms'].median(), inplace=True)

# %%
df['bathrooms'].fillna(df['bathrooms'].median(), inplace=True)

# Mengisi null value pada kolom bathrooms menggunakan median,
# dikarenakan pada data ini distribusi bedrooms cukup besar
# ada yang hanya mempunyai 1 bedrooms tapi juga ada yang mempunyai
# hingga 99 bedrooms. Sehingga bisa lebih menyeimbangkan outliers
# dibandingkan memakai modus
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23016\1140632577.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bathrooms'].fillna(df['bathrooms'].median(), inplace=True)

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
df['building_orientation'].value_counts().plot(kind='bar')
plt.title('Bar Plot of building_orientation')
plt.xlabel('building_orientation')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# Untuk mengetahui frequency building orientation yang palng disukai.
# Mayoritas properti menghadap ke selatan.

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
df['certificate'].value_counts().plot(kind='bar')
plt.title('Bar Plot of certificate')
plt.xlabel('certificate')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# Mayoritas rumah memiliki sudah shm

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
df['furnishing'].value_counts().plot(kind='bar')
plt.title('Bar Plot of furnishing')
plt.xlabel('furnishing')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# Mayoritas rumah unfurnished

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
df['property_condition'].value_counts().plot(kind='bar')
plt.title('Bar Plot of property_condition')
plt.xlabel('property_condition')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %%
# Dari 2 bar plot diatas, dapat diketahui bahwa ada data yang tertukar antara baru di furnishing, lalu unfurnished semi furnished di property condition.
# Seharusnya data baru ada di kolom property condition dan furnished semi furnished di kolom furnishing
# Sehingga dibawah ini akan dibenarkan

# Jika property_condition salah (berisi kata furnishing)
mask1 = df['property_condition'].isin(['unfurnished', 'semi furnished', 'furnished'])
df.loc[mask1, ['property_condition', 'furnishing']] = df.loc[mask1, ['furnishing', 'property_condition']].values

# Jika furnishing salah (berisi kata condition)
mask2 = df['furnishing'].isin(['bagus', 'baru', 'bagus sekali', 'sudah renovasi', 'butuh renovasi'])  # tambahkan kategori condition lain kalau ada
df.loc[mask2, ['property_condition', 'furnishing']] = df.loc[mask2, ['furnishing', 'property_condition']].values

# %%
# Bar Plot of furnishing after correction
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
df['furnishing'].value_counts().plot(kind='bar')
plt.title('Bar Plot of furnishing')
plt.xlabel('furnishing')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# Bar Plot of property_condition after correction
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
df['property_condition'].value_counts().plot(kind='bar')
plt.title('Bar Plot of property_condition')
plt.xlabel('property_condition')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# Visualisasi dibawah sudah benar dan akan lebih siap digunakan sebagai analisis
# Daripada ada data yang tertukar

# %%
df['building_orientation'].fillna('Unknown', inplace=True)
df['certificate'].fillna('Unknown', inplace=True)
df['furnishing'].fillna('Unknown', inplace=True)
df['property_condition'].fillna('Unknown', inplace=True)

# Untuk keempat kolom diatas, diputuskan untuk mengisi null value dengan unknown.
# Dikarenakan termasuk kategorikal data serta menjadi cara yang aman untuk tidak
# mengubah data dengan input yang berbeda
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23016\493927307.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['building_orientation'].fillna('Unknown', inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23016\493927307.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['building_age'].fillna(df['building_age'].median(), inplace=True)
df['year_built'].fillna(df['year_built'].median(), inplace=True)

# building_age dan year_built juga memiliki null value yang cukup banyak
# Dan kedua kolom tersebut null pada rows data yang sama, sehingga tidak dapat
# memakai salah satu kolom saja untuk mengetahui sudah berapa lama bangunan berdiri.
# Sehingga lebih baik diisi dengan median
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23016\686487735.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['building_age'].fillna(df['building_age'].median(), inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23016\686487735.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Selajutnya melakukan binning pada building_age. Agar lebih mudah untuk
# mengenali apakah bangunan ini termasuk baru ataupun tua
bins = [0, 10, 20, 100]  # batas umur bangunan
labels = ['New', 'Moderate', 'Old']  # label

df['building_age_bin'] = pd.cut(df['building_age'], bins=bins, labels=labels, right=True, include_lowest=True)

# cek hasil
print(df[['building_age', 'building_age_bin']].head(10))
# Out:
#    building_age building_age_bin
# 0           5.0              New
# 1           1.0              New
# 2           1.0              New
# 3           6.0              New
# 4           9.0              New
# 5           9.0              New
# 6           1.0              New
# 7           1.0              New
# 8           1.0              New
# 9           1.0              New

# %%
# Melakukan binning pada data price untuk mengelompokkan rumah yang mahal, medium, dan murah.
# Serta dapat mempermudah analisis terakhir

bins = [0, 2000000000, 3000000000, 4000000000, df['price_in_rp'].max()]
labels = ['Low', 'Medium', 'High', 'Luxury']

df['price_bin'] = pd.cut(df['price_in_rp'], bins=bins, labels=labels, include_lowest=True)

print(df[['price_in_rp', 'price_bin']].head(10))
# Out:
#     price_in_rp price_bin
# 0  2.990000e+09    Medium
# 1  1.270000e+09       Low
# 2  1.950000e+09       Low
# 3  3.300000e+09      High
# 4  4.500000e+09    Luxury
# 5  2.700000e+09    Medium
# 6  2.350000e+09    Medium
# 7  4.500000e+09    Luxury
# 8  2.900000e+09    Medium
# 9  2.700000e+09    Medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3547 entries, 0 to 3552
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   price_in_rp           3547 non-null   float64
#  1   title                 3547 non-null   object
#  2   address               3547 non-null   object
#  3   district              3547 non-null   object
#  4   city                  3547 non-null   object
#  5   lat                   3547 non-null   float64
#  6   long                  3547 non-null   float64
#  7   facilities            3547 non-null   object
#  8   property_type         3547 non-null   object
#  9   bedrooms              3547 non-null   float64
#  10  bathrooms             3547 non-null   float64
#  11  land_size_m2          3547 non-null   float64
#  12  building_size_m2      3547 non-null   float64
#  13  carports              3547 non-null   float64
#  14  certificate           3547 non-null   object
# ...

# %%
import matplotlib.pyplot as plt

# Buat histogram dan boxplot untuk land_size_m2 & building_size_m2
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Histogram land_size_m2
axes[0, 0].hist(df['land_size_m2'].dropna(), bins=50)
axes[0, 0].set_title("Histogram Land Size (m²)")

# Boxplot land_size_m2
axes[0, 1].boxplot(df['land_size_m2'].dropna(), vert=False)
axes[0, 1].set_title("Boxplot Land Size (m²)")

# Histogram building_size_m2
axes[1, 0].hist(df['building_size_m2'].dropna(), bins=50)
axes[1, 0].set_title("Histogram Building Size (m²)")

# Boxplot building_size_m2
axes[1, 1].boxplot(df['building_size_m2'].dropna(), vert=False)
axes[1, 1].set_title("Boxplot Building Size (m²)")

plt.tight_layout()
plt.show()

# Dari histogram dibawah, kita dapat mengetahui land_size_m2 dan building_size_m2 termasuk right skewed.
# Lalu dari hasil boxplot, kita dapat mengetahui bahwa sangat banyak outliers ekstrim yang ada di dalam data
# Sehingga saya tidak akan memakai data ekstrim tersebut.
# Pada next step akan hanya menggunakan 2000 land_size serta 3000 building size saja

# %%
# Membuang outliers yang terlalu ekstrim

df = df[df['land_size_m2'] <= 2000]
df = df[df['building_size_m2'] <= 3000]

plt.figure(figsize=(6, 4))
sns.boxplot(x=df['land_size_m2'])
plt.title('Boxplot of land_size_m2')
plt.xlabel('land_size_m2')
plt.show()

plt.figure(figsize=(6, 4))
sns.boxplot(x=df['building_size_m2'])
plt.title('Boxplot of building_size_m2')
plt.xlabel('building_size_m2')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='land_size_m2', y='building_size_m2', data=df)
plt.title('Scatter Plot of Luas Tanah vs Luas Bangunan')
plt.xlabel('Luas Tanah (m2)')

plt.ylabel('Luas Bangunan (m2)')
plt.show()

# Untuk mengetahui hubungan antara 2 variabel yaitu luas tanah dan luas bangunan
# Dari hasil scatter plot dibawah menunjukan korelasi positif karena titik" plot
# cenderung naik. Artinya semakin besar luas tanah, semakin besar juga luas bangunan
# Walaupun masih ada beberapa yang luas tanah besar namun luas bangunan tidak terlalu besar, ataupun sebaliknya

# %%
# Harga rata-rata per kota
avg_city = df.groupby('city')['price_in_rp'].mean().sort_values(ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(x=avg_city.index, y=avg_city.values, palette='viridis')
plt.title('Average Property Price per City')
plt.xlabel('City')
plt.ylabel('Average Price (Rp)')
plt.xticks(rotation=45)
plt.show()
# Dari hasil bar plot dibawah, dapat mengetahui hubungan city dan price rumah.
# Lokasi Jakarta Pusat memiliki rata" harga rumah tertinggi dan yang paling
# rendah adalah depok. Lokasi menjadi salah satu faktor tinggi nya harga rumah

# Furnishing effect
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='furnishing', y='price_in_rp')
plt.title('Price by Furnishing')
plt.show()
# Di semua kategori furnishing memiliki harga yang tersebar sangat jauh.
# Contoh di kategori unfurnished dengan outlier sangat ekstrim hingga 600M.
# Artinya furnishing bukan menjadi penentu utama dari harga. Mungkin lokasi/luas
# tanah yang berpengaruh besar terhadap harga rumah

# Furnishing vs price_bin
ct = pd.crosstab(df['price_bin'], df['furnishing'])
ct.plot(kind='bar')
plt.title("Distribusi Furnishing berdasarkan Price Bin")
plt.xlabel("Kategori Harga")
plt.ylabel("Jumlah Properti")
plt.show()
# Pada hasil bar chart memperlihatkan kategori low unfurnished mendominasi rumah yang tersedia.
# Di kategori high dan luxury, sering ditawarkan ruamh dengan semi furnished diikuti dengan unfurnished
# Sehingga kebanyakan rumah ditawarkan dengan harga tinggi tanpa lengkap furnished.
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23016\2370990696.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_city.index, y=avg_city.values, palette='viridis')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=df, x='building_age_bin', y='price_in_rp', order=['New','Moderate','Old'])
plt.title("Sebaran Harga Properti per Kategori Umur Bangunan")
plt.xlabel("Kategori Umur Bangunan")
plt.ylabel("Harga Properti (Rp)")
plt.ylim(0, df['price_in_rp'].quantile(0.95))  # biar outlier ekstrim tidak merusak skala
plt.show()

# Interpretasi dari binning building_age adalah dengan membuat boxplot untuk
# mengetahui bagaimana sebaran harga properti per kategori umur bangunan.
# Hasilnya diketahui bahwa umur bangunan new memiliki outliers yang sangat banyak
# dibandingkan kategori lainnya. Sehingga bisa jadi harga properti
# sangat dipengaruhi oleh umur bangunan itu sendiri, apakah new, moderate, old.
#

# %%
# Scatterplot: harga vs luas tanah
sns.scatterplot(data=df, x='land_size_m2', y='price_in_rp')
plt.title('Land Size vs Price')
plt.show()

# Scatterplot: harga vs luas bangunan
sns.scatterplot(data=df, x='building_size_m2', y='price_in_rp')
plt.title('Building Size vs Price')
plt.show()

# Hasil scatter plot antara land_size vs price dan building_size vs price, yang
# menunjukan korelasi yang positif karena titik" plot naik. Walaupun kenaikan tidak
# signifikan namun masih berpengaruh terhadap harga. Hal ini juga terbukti pada
# heatmap yang memperoleh nilai 0.47 dan 0.44

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# Heatmap digunakan untuk menunjukan kolerasi antar variabel dalam dataset
# Hasil heatmap dibawah menunjukan building size dengan price_in_rp menunjukan korelasi
# yang paling kuat dengan hasil 0.47, berati makin besar bangunan makin tinggi harga.
# Begitu juga dengan land_size, tetapi tidak sekuat building_size, diikuti dengan
# maid bedrooms dan main_bathrooms, jdi semakin tersedia nya fitur tersebut semakin tinggi harga. year_built
# dan price juga memiliki korelasi 0.09 berarti semakin baru dibangun, semakin tinggi
# harga rumah yang ditawarkan

# Sedangkan floor, lat, dan long memiliki kolerasi lemah terhadap harga, karena
# tidak berpengaruh langsung terhadap harga
